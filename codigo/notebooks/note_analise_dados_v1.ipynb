# %% [markdown]
# # Análise Inicial

# %%
# %pip install pandas
# %pip install numpy
# %pip install matplotlib
# %pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# ...
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('../data/AMOTRA_TOTAL.csv', sep=';')
# tirar limite de colunas
pd.set_option('display.max_columns', None)

# %%
data
# Out:
#              INDICE   LATITUDE  LONGITUDE CODIGO_ROTA  SEQUENCIA  \
# 0       401103972.0 -22.858956 -43.338632      70_324     3360.0
# 1       402281829.0 -22.830781 -43.395010       88_48      309.0
# 2       400507411.0 -22.821902 -43.415018       74_46      254.0
# 3       400533412.0 -22.834372 -43.410329       75_57       80.0
# 4       400515070.0 -22.861150 -43.338667      70_324     3180.0
# ...             ...        ...        ...         ...        ...
# 378294  403464358.0 -22.892057 -43.284250        72_9        1.0
# 378295  403492941.0 -22.886300 -43.351100       72_23      322.0
# 378296  403425139.0 -22.884305 -43.285893       86_10        1.0
# 378297  403543807.0 -22.839341 -43.376101       71_32      230.0
# 378298  403472949.0 -22.892110 -43.284340        72_9        1.0
#
#                   LOGRADOURO NUMERO
# 0       MONS INACIO DA SILVA    545
# 1                MARIA ELIZA     80
# 2                DONA LURDES      4
# 3           LUCIO JOSE FILHO     81
# ...

# %%
plt.scatter(data['LATITUDE'], data['LONGITUDE'], alpha=0.5)
plt.title('Plotagem de Latitude vs Longitude')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.show()

# %%
data['SEQUENCIA'].max()
# Out:
# 1330.0

# %%
data['SEQUENCIA'].min()
# Out:
# 0.0

# %%
data['SEQUENCIA'].mean()
# Out:
# 216.39184076328343

# %%
data['SEQUENCIA'].describe()
# Out:
# count    6079.000000
# mean      216.391841
# std       133.713333
# min         0.000000
# 25%       102.000000
# 50%       214.000000
# 75%       326.000000
# max      1330.000000
# Name: SEQUENCIA, dtype: float64

# %%
# ordenar por sequencia e depois codigo-rota
sorted_data = data.sort_values(by=['SEQUENCIA', 'CODIGO_ROTA'])
sorted_data
# Out:
#            INDICE   LATITUDE  LONGITUDE CODIGO_ROTA  SEQUENCIA  \
# 47    400157189.0 -22.811523 -43.317906        61_0        0.0
# 97    400157497.0 -22.810082 -43.318495        61_0        0.0
# 128   400157466.0 -22.809100 -43.318775        61_0        0.0
# 204   400157585.0 -22.813984 -43.317643        61_0        0.0
# 575   400157597.0 -22.814743 -43.317417        61_0        0.0
# ...           ...        ...        ...         ...        ...
# 2151  401206163.0 -22.805238 -43.328272      83_115      960.0
# 69    401519367.0 -22.805495 -43.328419      83_115      961.0
# 64    400432494.0 -22.805613 -43.328486      83_115      962.0
# 62    401563782.0 -22.805007 -43.328141      83_115      964.0
# 904   402846599.0 -22.809777 -43.331127        84_3     1330.0
#
#                LOGRADOURO  NUMERO
# 47          ANTONIO LOPES    81.0
# 97        LOURIVAL INACIO    39.0
# 128       LOURIVAL INACIO     8.0
# 204       LOURIVAL INACIO   132.0
# ...

# %%
data['SEQUENCIA'].unique().size
# Out:
# 510

# %%
import random

# Gerar uma lista de cores aleatórias do mesmo tamanho que o número de valores únicos na coluna 'sequencia'
cores_aleatorias = [plt.cm.colors.to_hex(random.choice(plt.cm.tab10.colors)) for _ in range(len(data['CODIGO_ROTA'].unique()))]

# Criar um dicionário mapeando valores únicos da coluna 'sequencia' para cores aleatórias
cores_por_sequencia = dict(zip(data['CODIGO_ROTA'].unique(), cores_aleatorias))

# Criar uma lista de cores com base nos valores da coluna 'sequencia'
cores = [cores_por_sequencia[sequencia] for sequencia in data['CODIGO_ROTA']]

# Plotar os pontos com cores diferentes para cada valor único da coluna 'sequencia'
plt.scatter(data['LATITUDE'], data['LONGITUDE'], c=cores, alpha=0.5)
plt.title('Plotagem de Latitude vs Longitude')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.show()

# %%
data['CODIGO_ROTA'].unique().size
# Out:
# 61

# %%
filtered_data = sorted_data[(sorted_data['CODIGO_ROTA'] == '72_203')]
filtered_data
# Out:
#            INDICE   LATITUDE  LONGITUDE CODIGO_ROTA  SEQUENCIA  \
# 3436  403526377.0 -22.812222 -43.327796      72_203        1.0
# 5080  400547299.0 -22.810383 -43.329637      72_203        1.0
# 1167  400086729.0 -22.810328 -43.329741      72_203        2.0
# 439   400252802.0 -22.810285 -43.329820      72_203        3.0
# 5481  400145353.0 -22.810236 -43.329907      72_203        4.0
# ...           ...        ...        ...         ...        ...
# 790   400451901.0 -22.810993 -43.329971      72_203      420.0
# 3176  400511948.0 -22.810993 -43.329971      72_203      421.0
# 460   400494409.0 -22.811122 -43.330052      72_203      422.0
# 215   401732570.0 -22.811007 -43.330249      72_203      423.0
# 859   402815470.0 -22.810163 -43.330786      72_203      424.0
#
#                    LOGRADOURO  NUMERO
# 3436  ORGANISTA ANTONIO SILVA   211.0
# 5080         GAL OSCILIO MAIA   163.0
# 1167         GAL OSCILIO MAIA   159.0
# 439          GAL OSCILIO MAIA   147.0
# ...

# %%
# Plotar os pontos com cores diferentes para cada valor único da coluna 'sequencia'
plt.scatter(filtered_data['LATITUDE'], filtered_data['LONGITUDE'], alpha=0.5)
plt.title('Plotagem de Latitude vs Longitude')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.show()

# %%
# Gerar uma lista de cores aleatórias do mesmo tamanho que o número de valores únicos na coluna 'sequencia'
cores_aleatorias = [plt.cm.colors.to_hex(random.choice(plt.cm.tab10.colors)) for _ in range(len(filtered_data['SEQUENCIA'].unique()))]

# Criar um dicionário mapeando valores únicos da coluna 'sequencia' para cores aleatórias
cores_por_sequencia = dict(zip(filtered_data['SEQUENCIA'].unique(), cores_aleatorias))

# Criar uma lista de cores com base nos valores da coluna 'sequencia'
cores = [cores_por_sequencia[sequencia] for sequencia in filtered_data['SEQUENCIA']]

# Plotar os pontos com cores diferentes para cada valor único da coluna 'sequencia'
plt.scatter(filtered_data['LATITUDE'], filtered_data['LONGITUDE'], c=cores, alpha=0.5)
plt.title('Plotagem de Latitude vs Longitude')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.show()

# %%
# Seus dados de latitude e longitude
latitude = filtered_data['LATITUDE']
longitude = filtered_data['LONGITUDE']

plt.scatter(latitude, longitude, alpha=0.5)

plt.plot(latitude, longitude, color='gray', linestyle='-')

# Adicionando título e rótulos dos eixos
plt.title('Plotagem de Latitude vs Longitude com Linhas Conectando Pontos')
plt.xlabel('Longitude')
plt.ylabel('Latitude')

# Mostrando o gráfico
plt.show()

# %%
# print filtered_data that the longitude is greater than -22.800
filtered_data[filtered_data['LATITUDE'] > -22.807]
# Out:
#           INDICE   LATITUDE  LONGITUDE CODIGO_ROTA  SEQUENCIA  \
# 562  400381569.0 -22.803525 -43.327431      72_203      107.0
#
#             LOGRADOURO  NUMERO
# 562  OTAVIO MANGABEIRA   622.0

# %%
max_num = data['NUMERO'].max()
box_data = data.copy()
# excluir os dados com valor máximo
box_data['NUMERO'] = box_data['NUMERO'].apply(lambda x: x if x != max_num else np.nan)
# excluir dados faltantes
box_data = box_data.dropna(subset=['NUMERO'])

sns.boxplot(x=box_data['NUMERO'])
plt.title('Boxplot de Numero por Codigo Rota')
plt.show()

# %%
# boxplot da coluna numero
sns.boxplot(x=data['NUMERO'])
plt.title('Boxplot da coluna Numero')
plt.show()

# %%
data['NUMERO'].describe()
# Out:
# count     6077.000000
# mean       341.013000
# std       1328.475353
# min          0.000000
# 25%         97.000000
# 50%        213.000000
# 75%        460.000000
# max      99975.000000
# Name: NUMERO, dtype: float64

# %%
data['LATITUDE'].describe()
# Out:
# count    6079.000000
# mean      -22.809978
# std         0.003608
# min       -22.819022
# 25%       -22.812493
# 50%       -22.810003
# 75%       -22.807212
# max       -22.801733
# Name: LATITUDE, dtype: float64

# %%
# check for duplicates in data[LATITUDE, LONGITUDE]
duplicates = data[data.duplicated(subset=['LATITUDE', 'LONGITUDE'], keep=False)]
duplicates
# Out:
#            INDICE   LATITUDE  LONGITUDE CODIGO_ROTA  SEQUENCIA  \
# 15    400086611.0 -22.810693 -43.330415       604_3       28.0
# 22    402279719.0 -22.818946 -43.318989      72_201        4.0
# 31    400218852.0 -22.817238 -43.322168      72_201       12.0
# 41    400397647.0 -22.810354 -43.318004      72_212      285.0
# 45    400360977.0 -22.807347 -43.327218      72_206      168.0
# ...           ...        ...        ...         ...        ...
# 6062  402304649.0 -22.817103 -43.319826      72_201      192.0
# 6065  401924572.0 -22.805256 -43.323471      72_209      350.0
# 6068  402622242.0 -22.806922 -43.323692      72_208      138.0
# 6071  403220629.0 -22.809295 -43.321676      72_210        2.0
# 6078  402174328.0 -22.815054 -43.322584      72_201       57.0
#
#                LOGRADOURO  NUMERO
# 15    RODOLFO CHAMBELLAND   387.0
# 22             PRES DUTRA   142.0
# 31       PRESIDENTE DUTRA   482.0
# 41      GREGORIO DE MATOS   527.0
# ...

# %%
total = data.shape[0]

# %%
parcial = data.shape[0] - duplicates.shape[0]

# %%
(parcial/total) * 100
# Out:
# 60.618522783352525

# %%
data[(data['LATITUDE'] == -22.810693) & (data['LONGITUDE'] == -43.330415)]
# Out:
#            INDICE   LATITUDE  LONGITUDE CODIGO_ROTA  SEQUENCIA  \
# 15    400086611.0 -22.810693 -43.330415       604_3       28.0
# 2911  400478065.0 -22.810693 -43.330415       604_3       31.0
# 3634  400117833.0 -22.810693 -43.330415       604_3       32.0
# 4499  401565756.0 -22.810693 -43.330415       604_3       33.0
# 4785  400476405.0 -22.810693 -43.330415       604_3       30.0
#
#                LOGRADOURO  NUMERO
# 15    RODOLFO CHAMBELLAND   387.0
# 2911  RODOLFO CHAMBELLAND    42.0
# 3634  RODOLFO CHAMBELLAND    12.0
# 4499  RODOLFO CHAMBELLAND    37.0
# 4785  RODOLFO CHAMBELLAND    34.0

# %%
#

# %% [markdown]
# # Análise aprofundada

# %%
# copy data
data_copy = data.copy()

# translate the latitude and longitude so that the minimum latitude and longitude are 0
data_copy['LATITUDE'] = data_copy['LATITUDE'] - data_copy['LATITUDE'].min()
data_copy['LONGITUDE'] = data_copy['LONGITUDE'] - data_copy['LONGITUDE'].min()

# plot the translated latitude and longitude
plt.scatter(data_copy['LATITUDE'], data_copy['LONGITUDE'], alpha=0.5)
plt.title('Plotagem de Latitude vs Longitude')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.show()

# %%
def degrees_to_radians(degrees):
    return degrees * np.pi / 180

def convert_to_cartesian(latitude, longitude):
    lat_rad = degrees_to_radians(latitude)
    lon_rad = degrees_to_radians(longitude)
    x = np.cos(lat_rad) * np.cos(lon_rad)
    y = np.cos(lat_rad) * np.sin(lon_rad)
    return x, y

def euclidian_distance(x1, y1, x2, y2):
    return np.sqrt((x1 - x2)**2 + (y1 - y2)**2)

# %%
# create x and y columns
data_copy['LAT_RAD'] = data_copy['LATITUDE'].apply(degrees_to_radians)
data_copy['LON_RAD'] = data_copy['LONGITUDE'].apply(degrees_to_radians)

# create x and y columns
data_copy['X'], data_copy['Y'] = zip(*data_copy.apply(lambda row: convert_to_cartesian(row['LAT_RAD'], row['LON_RAD']), axis=1))

# plot the translated latitude and longitude
plt.scatter(data_copy['X'], data_copy['Y'], alpha=0.5)
plt.title('Plotagem de X vs Y')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %%
# %pip install scikit-learn
# Out:
# ...
#
# ...

# %%
# use a knn model to cluester the data
from sklearn.cluster import KMeans

# create a kmeans model
kmeans = KMeans(n_clusters=30, random_state=42)

# fit the model
kmeans.fit(data_copy[['LAT_RAD', 'LON_RAD']])
data_copy['CLUSTER'] = kmeans.labels_

# plot the clusters
plt.scatter(data_copy['X'], data_copy['Y'], c=data_copy['CLUSTER'], alpha=0.5)
plt.title('Plotagem de X vs Y com Clusters')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()
# Out:
# c:\Users\Inteli\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
# plot the clusters from the original data
plt.scatter(data['LATITUDE'], data['LONGITUDE'], c=data_copy['CLUSTER'], alpha=0.5)
plt.title('Plotagem de Latitude vs Longitude com Clusters')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.show()

# %%
data_copy[data_copy['CLUSTER'] == 1].shape
# Out:
# (186, 12)

# %%
from sklearn.metrics.pairwise import euclidean_distances

# Calculate distance matrix
dist_matrix = euclidean_distances(data_copy[['X', 'Y']])

def nearest_neighbor(dist_matrix):
    n = len(dist_matrix)
    visited = [False] * n
    tour = [0]  # starting from node 0

    while len(tour) < n:
        current_node = tour[-1]
        min_dist = float('inf')
        nearest_node = None

        for neighbor in range(n):
            if not visited[neighbor] and dist_matrix[current_node][neighbor] < min_dist:
                min_dist = dist_matrix[current_node][neighbor]
                nearest_node = neighbor

        tour.append(nearest_node)
        visited[nearest_node] = True

    # Add back the starting node to complete the tour
    tour.append(tour[0])
    
    return tour

tsp_tour = nearest_neighbor(dist_matrix)

# %%
# tour and distance of the tour
tsp_tour, sum([dist_matrix[tsp_tour[i]][tsp_tour[i+1]] for i in range(len(tsp_tour) - 1)])
# Out:
# ([0,
#   0,
#   141,
#   842,
#   1036,
#   1111,
#   840,
#   1418,
#   2135,
#   2449,
#   6,
#   2540,
#   1911,
#   217,
#   659,
#   1988,
#   26,
#   40,
#   61,
#   195,
#   94,
#   30,
#   705,
#   1306,
#   181,
#   903,
#   1157,
#   1492,
#   829,
#   1300,
#   317,
#   341,
#   1579,
#   1468,
#   2546,
#   2704,
#   1299,
#   496,
#   507,
#   649,
#   888,
#   5,
#   1046,
#   1353,
#   1485,
#   2603,
#   2630,
#   2744,
#   2872,
#   1317,
#   2636,
#   2643,
#   3350,
#   3518,
#   4617,
#   2844,
#   3012,
#   1704,
#   2903,
#   3444,
#   2836,
#   337,
#   1136,
#   213,
#   593,
#   1166,
#   1547,
#   937,
#   1161,
#   608,
#   1539,
#   1246,
#   24,
#   487,
#   682,
#   1434,
#   2056,
#   2104,
#   2114,
#   2391,
#   3236,
#   3010,
#   1441,
#   1497,
#   1618,
#   3580,
#   3680,
#   2277,
#   1484,
#   2197,
#   2475,
#   2214,
#   2291,
#   2663,
#   3496,
#   3590,
#   3638,
#   3545,
#   1509,
#   1989,
#   2356,
#   3132,
#   3103,
#   3438,
# ...

# %%
data_copy.shape
# Out:
# (6079, 12)

# %% [markdown]
# ## Versão para OR-Tools

# %%
ortools_data = data_copy.copy()

# %%
ortools_data.head()
# Out:
#         INDICE  LATITUDE  LONGITUDE CODIGO_ROTA  SEQUENCIA  \
# 0  400121201.0  0.007562   0.004635      72_203      269.0
# 1  400341582.0  0.009033   0.001953      72_204       80.0
# 2  400133758.0  0.008564   0.006916      72_202      391.0
# 3  400091624.0  0.009778   0.004925      72_202      175.0
# 4  400003468.0  0.015552   0.005637      72_207      205.0
#
#            LOGRADOURO  NUMERO
# 0        ATILIO PARIM   509.0
# 1        ATILIO PARIM   201.0
# 2     MIN ARTUR COSTA   404.0
# 3    VIANA DO CASTELO    39.0
# 4  FLAVIO DA SILVEIRA    12.0

# %%
import math

filter_data = data_copy.copy()

# Convertendo as coordenadas para metros usando NumPy
x = filter_data['LATITUDE'].values * 10000000 / 90  # 90 graus == 10.000km
k = np.cos(filter_data['LATITUDE'].values * np.pi / 180.0)
y = filter_data['LONGITUDE'].values * k * 10000000 / 90  # 90 graus == 10.000km

# Calculando os valores mínimos
minx1 = np.min(x)
minx2 = np.min(y)

# Ajustando os valores relativos ao mínimo encontrado
x_metros = (x - minx1).astype(int)
y_metros = (y - minx2).astype(int)

# Adicionando as colunas ao DataFrame
filter_data['x_metros'] = x_metros
filter_data['y_metros'] = y_metros

filter_data[['x_metros', 'y_metros']]
# Out:
#       x_metros  y_metros
# 0          840       514
# 1         1003       216
# 2          951       768
# 3         1086       547
# 4         1727       626
# ...        ...       ...
# 6074      1504      1042
# 6075      1582       370
# 6076      1059      1247
# 6077      1548       330
# 6078       440       953
#
# [6079 rows x 2 columns]

# %%
from sklearn.cluster import KMeans

# cluester the filter_data
kmeans = KMeans(n_clusters=30, random_state=42)
kmeans.fit(filter_data[['x_metros', 'y_metros']])
filter_data['CLUSTER'] = kmeans.labels_

# plot the clusters
plt.scatter(filter_data['x_metros'], filter_data['y_metros'], c=filter_data['CLUSTER'], alpha=0.5)
plt.title('Plotagem de X vs Y com Clusters')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()
# Out:
# c:\Users\Inteli\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
filter_data.head()
# Out:
#         INDICE  LATITUDE  LONGITUDE CODIGO_ROTA  SEQUENCIA  \
# 0  400121201.0  0.007562   0.004635      72_203      269.0
# 1  400341582.0  0.009033   0.001953      72_204       80.0
# 2  400133758.0  0.008564   0.006916      72_202      391.0
# 3  400091624.0  0.009778   0.004925      72_202      175.0
# 4  400003468.0  0.015552   0.005637      72_207      205.0
#
#            LOGRADOURO  NUMERO  x_metros  y_metros  CLUSTER
# 0        ATILIO PARIM   509.0       840       514        2
# 1        ATILIO PARIM   201.0      1003       216        5
# 2     MIN ARTUR COSTA   404.0       951       768       24
# 3    VIANA DO CASTELO    39.0      1086       547       24
# 4  FLAVIO DA SILVEIRA    12.0      1727       626       26

# %%
filter_data[filter_data['CLUSTER'] == 30].shape
# Out:
# (0, 10)

# %%
filter_data[filter_data['CLUSTER'] == 0]
# Out:
#            INDICE  LATITUDE  LONGITUDE CODIGO_ROTA  SEQUENCIA  \
# 18    401438158.0  0.014520   0.003173       604_3        1.0
# 21    401438278.0  0.014518   0.002986        94_0        0.0
# 24    400480946.0  0.016509   0.004564      83_110      649.0
# 25    401438165.0  0.014522   0.003281        94_0        0.0
# 26    400482461.0  0.016486   0.004462      83_110      644.0
# ...           ...       ...        ...         ...        ...
# 5372  400108769.0  0.015628   0.004005      72_207      295.0
# 5429  401206157.0  0.014166   0.004496      72_207      375.0
# 5454  400382116.0  0.014024   0.004443      72_207      384.0
# 5517  400462596.0  0.014734   0.005336      72_207       42.0
# 6075  403469601.0  0.014240   0.003333      83_115        1.0
#
#                      LOGRADOURO  NUMERO  x_metros  y_metros  CLUSTER
# 18     LIRIO-FAV PHIDIAS TAVORA    60.0      1613       352        0
# 21    ORQUIDEA-F PHIDIAS TAVORA    42.0      1613       331        0
# ...

# %%
# criar lista com as tuplas de coordenadas
locations = list(zip(filter_data['x_metros'], filter_data['y_metros']))
locations
# Out:
# [(840, 514),
#  (1003, 216),
#  (951, 768),
#  (1086, 547),
#  (1727, 626),
#  (709, 469),
#  (842, 511),
#  (1046, 792),
#  (931, 1391),
#  (993, 236),
#  (1164, 928),
#  (974, 250),
#  (1201, 109),
#  (1792, 811),
#  (1803, 796),
#  (925, 83),
#  (666, 418),
#  (1363, 543),
#  (1613, 352),
#  (1044, 791),
#  (1291, 1069),
#  (1613, 331),
#  (8, 1352),
#  (812, 119),
#  (1834, 507),
#  (1613, 364),
#  (1831, 495),
#  (1613, 334),
#  (788, 1460),
#  (1819, 1130),
#  (1827, 488),
#  (198, 999),
#  (808, 1480),
#  (812, 119),
#  (1027, 787),
#  (820, 1521),
#  (443, 840),
#  (1830, 452),
#  (1809, 792),
#  (934, 1542),
#  (1666, 495),
#  (963, 1462),
#  (874, 183),
#  (1238, 419),
#  (1243, 855),
#  (1297, 438),
#  (690, 1560),
#  (833, 1473),
#  (860, 678),
#  (974, 447),
#  (1005, 239),
#  (1794, 597),
#  (878, 667),
#  (933, 806),
#  (735, 839),
#  (1720, 652),
#  (735, 301),
#  (527, 861),
#  (824, 808),
#  (408, 1076),
#  (989, 779),
#  (1740, 494),
#  (1557, 335),
# ...

# %%
from ortools.constraint_solver import routing_enums_pb2
from ortools.constraint_solver import pywrapcp

# %%
# [START data_model]
def create_data_model():
    """Stores the data for the problem."""
    data = {}
    # Locations in block units
    data["locations"] = locations
    print("Numero de pontos:", len(data["locations"]))
    data["num_vehicles"] = 1
    data["depot"] = 0
    return data
    # [END data_model]

# [START distance_callback]
def compute_euclidean_distance_matrix(locations):
    """Creates callback to return distance between points."""
    distances = {}
    for from_counter, from_node in enumerate(locations):
        distances[from_counter] = {}
        for to_counter, to_node in enumerate(locations):
            if from_counter == to_counter:
                distances[from_counter][to_counter] = 0
            else:
                # Euclidean distance
                distances[from_counter][to_counter] = int(
                    math.hypot((from_node[0] - to_node[0]), (from_node[1] - to_node[1]))
                )
    return distances
    # [END distance_callback]

# [START solution_printer]
def print_solution(manager, routing, solution):
    """Prints solution on console."""
    print(f"Funcao Objetivo: {solution.ObjectiveValue()}")
    index = routing.Start(0)
    plan_output = "Rota:\n"
    route_distance = 0
    while not routing.IsEnd(index):
        plan_output += f" {manager.IndexToNode(index)} ->"
        previous_index = index
        index = solution.Value(routing.NextVar(index))
        route_distance += routing.GetArcCostForVehicle(previous_index, index, 0)
    plan_output += f" {manager.IndexToNode(index)}\n"
    print(plan_output)
    plan_output += f"Distancia percorrida: {route_distance}m\n"
    # [END solution_printer]

def main():
    """Entry point of the program."""
    # Instantiate the data problem.
    # [START data]
    data = create_data_model()
    # [END data]

    # Create the routing index manager.
    # [START index_manager]
    manager = pywrapcp.RoutingIndexManager(
        len(data["locations"]), data["num_vehicles"], data["depot"]
    )
    # [END index_manager]

    # Create Routing Model.
    # [START routing_model]
    routing = pywrapcp.RoutingModel(manager)
    # [END routing_model]

    # [START transit_callback]
    distance_matrix = compute_euclidean_distance_matrix(data["locations"])

    def distance_callback(from_index, to_index):
        """Returns the distance between the two nodes."""
        # Convert from routing variable Index to distance matrix NodeIndex.
        from_node = manager.IndexToNode(from_index)
        to_node = manager.IndexToNode(to_index)
        return distance_matrix[from_node][to_node]

    transit_callback_index = routing.RegisterTransitCallback(distance_callback)
    # [END transit_callback]

    # Define cost of each arc.
    # [START arc_cost]
    routing.SetArcCostEvaluatorOfAllVehicles(transit_callback_index)
    # [END arc_cost]

    # Setting first solution heuristic.
    # [START parameters]
    search_parameters = pywrapcp.DefaultRoutingSearchParameters()
    search_parameters.first_solution_strategy = (
        routing_enums_pb2.FirstSolutionStrategy.PATH_CHEAPEST_ARC
    )
    # [END parameters]

    # Solve the problem.
    # [START solve]
    solution = routing.SolveWithParameters(search_parameters)
    # [END solve]

    # Print solution on console.
    # [START print_solution]
    if solution:
        print_solution(manager, routing, solution)
    # [END print_solution]

# %%
main()
# Out:
# Numero de pontos: 6079

# %%
# dist_matrix = euclidean_distances(ortools_data[['X', 'Y']])
# dist_matrix.shape

# manhattan distance
dist_matrix = np.abs(ortools_data[['X', 'Y']].values[:, None] - ortools_data[['X', 'Y']].values).sum(-1)
dist_matrix.shape
# Out:
# (6079, 6079)

# %%
# %pip install ortools
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from ortools.constraint_solver import routing_enums_pb2
from ortools.constraint_solver import pywrapcp

def create_data_model(dist_matrix, num_vehicles, depot):
    data = {}
    data['distance_matrix'] = dist_matrix.tolist()
    data['num_vehicles'] = num_vehicles
    data['depot'] = depot
    return data

def print_solution(data, manager, routing, solution):
    """Prints solution on console."""
    print(f"Objective: {solution.ObjectiveValue()}")
    max_route_distance = 0
    for vehicle_id in range(data["num_vehicles"]):
        index = routing.Start(vehicle_id)
        plan_output = f"Route for vehicle {vehicle_id}:\n"
        route_distance = 0  # Initialize route distance inside the loop
        while not routing.IsEnd(index):
            plan_output += f" {manager.IndexToNode(index)} -> "
            previous_index = index
            index = solution.Value(routing.NextVar(index))
            route_distance += routing.GetArcCostForVehicle(
                previous_index, index, vehicle_id
            )  # Update route distance correctly
        plan_output += f"{manager.IndexToNode(index)}\n"
        plan_output += f"Distance of the route: {route_distance}m\n"
        print(plan_output)
        max_route_distance = max(route_distance, max_route_distance)
    print(f"Maximum of the route distances: {max_route_distance}m")


def routing_problem(data):
    def distance_callback(from_index, to_index):
        from_node = manager.IndexToNode(from_index)
        to_node = manager.IndexToNode(to_index)
        return data['distance_matrix'][from_node][to_node]

    manager = pywrapcp.RoutingIndexManager(len(data['distance_matrix']), data['num_vehicles'], data['depot'])
    routing = pywrapcp.RoutingModel(manager)

    transit_callback_index = routing.RegisterTransitCallback(distance_callback)

    # Define cost of each arc.
    routing.SetArcCostEvaluatorOfAllVehicles(transit_callback_index)

    # Add Distance constraint.
    dimension_name = "Distance"
    routing.AddDimension(
        transit_callback_index,
        0,  # no slack
        10000,  # vehicle maximum travel distance
        True,  # start cumul to zero
        dimension_name,
    )
    distance_dimension = routing.GetDimensionOrDie(dimension_name)
    distance_dimension.SetGlobalSpanCostCoefficient(100)

    search_parameters = pywrapcp.DefaultRoutingSearchParameters()
    search_parameters.first_solution_strategy = (routing_enums_pb2.FirstSolutionStrategy.PATH_CHEAPEST_ARC)

    solution = routing.SolveWithParameters(search_parameters)

    # Print solution on console.
    if solution:
        print_solution(data, manager, routing, solution)
    else:
        print("No solution found !")
    return solution, manager, routing

# %%
data_model = create_data_model(dist_matrix, 1, 0)

solution, manager, routing = routing_problem(data_model)
# Out:
# Objective: 0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: 'float' object cannot be interpreted as an integer
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# Cell In[46], line 3
#       1 data_model = create_data_model(dist_matrix, 1, 0)
# ----> 3 solution, manager, routing = routing_problem(data_model)
#
# Cell In[45], line 66, in routing_problem(data)
#      64 # Print solution on console.
#      65 if solution:
# ---> 66     print_solution(data, manager, routing, solution)
#      67 else:
#      68     print("No solution found !")
#
# Cell In[45], line 23, in print_solution(data, manager, routing, solution)
#      21     previous_index = index
#      22     index = solution.Value(routing.NextVar(index))
# ...

# %%
data_model['distance_matrix'][0][1]
# Out:
# 8.169859744234561e-07

# %%
# read json file
import json
with open('result.json', 'r') as file:
    result_json = json.load(file)

result_json
# Out:
# {'response': [{'funcao_objetivo': 1354,
#    'rota': [0,
#     118,
#     115,
#     66,
#     98,
#     78,
#     91,
#     141,
#     20,
#     132,
#     123,
#     121,
#     42,
#     108,
#     11,
#     128,
#     14,
#     9,
#     71,
#     26,
#     52,
#     105,
#     86,
#     75,
#     30,
#     4,
#     135,
#     32,
#     102,
#     6,
#     125,
#     83,
#     47,
#     62,
#     49,
#     81,
#     13,
#     143,
#     117,
#     109,
#     99,
#     43,
#     65,
#     85,
#     134,
#     57,
#     139,
#     76,
#     92,
#     103,
#     27,
#     68,
#     70,
#     119,
#     101,
#     58,
#     41,
#     93,
#     33,
#     38,
#     31,
#     127,
#     100,
#     94,
#     1,
#     140,
#     120,
#     107,
#     112,
#     45,
#     61,
#     37,
#     69,
#     12,
#     64,
#     111,
#     8,
#     116,
#     82,
#     133,
#     73,
#     104,
#     39,
#     44,
#     7,
#     53,
#     36,
#     60,
#     59,
#     87,
#     3,
#     95,
# ...

# %%
cluested_data = pd.read_csv('cluestered_data_with_routes.csv', sep=';')
cluested_data[cluested_data['CLUSTER']==0]
# Out:
#            INDICE   LATITUDE  LONGITUDE CODIGO_ROTA  SEQUENCIA  \
# 149   401537825.0 -22.809062 -43.320463      72_210      161.0
# 239   402364814.0 -22.807947 -43.319689      72_210      433.0
# 267   400100232.0 -22.807696 -43.320342      72_210      131.0
# 326   400155235.0 -22.806996 -43.320200      72_210      327.0
# 342   400152895.0 -22.808130 -43.319625      72_210      427.0
# ...           ...        ...        ...         ...        ...
# 5798  400091842.0 -22.807949 -43.319788      72_210      408.0
# 5893  400100209.0 -22.809062 -43.319840      72_211      293.0
# 5978  401509685.0 -22.809172 -43.320428      72_211      288.0
# 5984  400089791.0 -22.808768 -43.320212      72_210      158.0
# 6011  402055229.0 -22.807298 -43.320563      72_210      137.0
#
#              LOGRADOURO  NUMERO  x_metros  y_metros  CLUSTER  NUM_ROTA
# 149       GEORGES BIZET   221.0      1106      1087        0       145
# ...

# %%
# plot cluested_data[cluested_data['CLUSTER']==0]
# plot with the sequence of the points
# Ordenar os dados pela coluna 'NUM_ROTA'
sorted_data = cluested_data[cluested_data['CLUSTER'] == 0].sort_values(by='NUM_ROTA')

# Adicionar o primeiro ponto ao final para fechar o ciclo
closed_data = pd.concat([sorted_data, sorted_data.iloc[[0]]])

# Plotar os pontos
plt.scatter(closed_data['LATITUDE'], closed_data['LONGITUDE'], alpha=0.5)

# Plotar a linha que representa a rota percorrida, incluindo a volta ao ponto inicial
plt.plot(closed_data['LATITUDE'], closed_data['LONGITUDE'], color='gray', linestyle='-')

# Adicionar título e rótulos aos eixos
plt.title('Plotagem de Latitude vs Longitude')
plt.xlabel('Longitude')
plt.ylabel('Latitude')

# Mostrar o gráfico
plt.show()

# %%
# Configurar o gráfico
plt.figure(figsize=(10, 8))

# Iterar sobre cada cluster e plotar os pontos e as conexões
for cluster_id in cluested_data['CLUSTER'].unique():
    # Filtrar os dados do cluster atual
    cluster_data = cluested_data[cluested_data['CLUSTER'] == cluster_id]
    
    # Ordenar os dados pela coluna 'NUM_ROTA'
    sorted_data = cluster_data.sort_values(by='NUM_ROTA')
    
    # Adicionar o primeiro ponto ao final para fechar o ciclo
    closed_data = pd.concat([sorted_data, sorted_data.iloc[[0]]])
    
    # Plotar os pontos
    plt.scatter(closed_data['LATITUDE'], closed_data['LONGITUDE'], alpha=0.5, label=f'Cluster {cluster_id}')
    
    # Plotar a linha que representa a rota percorrida, incluindo a volta ao ponto inicial
    plt.plot(closed_data['LATITUDE'], closed_data['LONGITUDE'], linestyle='-')

# Adicionar título e rótulos aos eixos
plt.title('Plotagem de Latitude vs Longitude por Cluster')
plt.xlabel('Longitude')
plt.ylabel('Latitude')

# Adicionar legenda
plt.legend()

# Mostrar o gráfico
plt.show()

# %%
# plot cluestered_data
plt.scatter(cluested_data['LATITUDE'], cluested_data['LONGITUDE'], c=cluested_data['CLUSTER'], alpha=0.5)
plt.title('Plotagem de Latitude vs Longitude com Clusters')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.show()

# %%
# %pip install geopandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import geopandas as gpd

# Substitua o caminho abaixo pelo caminho para o seu arquivo shapefile
shapefile_path = 'caminho/para/seu/arquivo.shp'

# Ler o arquivo shapefile usando geopandas
gdf = gpd.read_file(shapefile_path)

# Visualizar os primeiros registros do GeoDataFrame
print(gdf.head())

# Plotar os dados
gdf.plot()
plt.title('Logradouros do Rio de Janeiro')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.show()

# %%
cluested_data = pd.read_csv('cluestered_data_with_routes5.csv', sep=';')
cluested_data[cluested_data['CLUSTER']==0]
# Out:
#            INDICE   LATITUDE  LONGITUDE CODIGO_ROTA  SEQUENCIA  \
# 149   401537825.0 -22.809062 -43.320463      72_210      161.0
# 239   402364814.0 -22.807947 -43.319689      72_210      433.0
# 267   400100232.0 -22.807696 -43.320342      72_210      131.0
# 326   400155235.0 -22.806996 -43.320200      72_210      327.0
# 342   400152895.0 -22.808130 -43.319625      72_210      427.0
# ...           ...        ...        ...         ...        ...
# 5798  400091842.0 -22.807949 -43.319788      72_210      408.0
# 5893  400100209.0 -22.809062 -43.319840      72_211      293.0
# 5978  401509685.0 -22.809172 -43.320428      72_211      288.0
# 5984  400089791.0 -22.808768 -43.320212      72_210      158.0
# 6011  402055229.0 -22.807298 -43.320563      72_210      137.0
#
#              LOGRADOURO  NUMERO  x_metros  y_metros  CLUSTER  ROUTE_NUM
# 149       GEORGES BIZET   221.0      1106      1087        0          0
# ...

# %%
sorted_data = cluested_data[cluested_data['CLUSTER'] == 0].sort_values(by='ROUTE_NUM')

# Adicionar o primeiro ponto ao final para fechar o ciclo
closed_data = pd.concat([sorted_data, sorted_data.iloc[[0]]])

# Plotar os pontos
plt.scatter(closed_data['LATITUDE'], closed_data['LONGITUDE'], alpha=0.5)

# Plotar a linha que representa a rota percorrida, incluindo a volta ao ponto inicial
plt.plot(closed_data['LATITUDE'], closed_data['LONGITUDE'], color='gray', linestyle='-')

# Adicionar título e rótulos aos eixos
plt.title('Plotagem de Latitude vs Longitude')
plt.xlabel('Longitude')
plt.ylabel('Latitude')

# Mostrar o gráfico
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_27704\25227466.py in ?()
# ----> 1 sorted_data = cluested_data[cluested_data['CLUSTER'] == 0].sort_values(by='NUM_ROTA')
#       2
#       3 # Adicionar o primeiro ponto ao final para fechar o ciclo
#       4 closed_data = pd.concat([sorted_data, sorted_data.iloc[[0]]])
#
# c:\Users\Inteli\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6940             )
#    6941         elif len(by):
#    6942             # len(by) == 1
#    6943
# -> 6944             k = self._get_label_or_level_values(by[0], axis=axis)
#    6945
#    6946             # need to rewrap column in Series to apply key function
#    6947             if key is not None:
#
# ...
